# %% [markdown]
# # Кластеры. Когда нужно больше точек

# %% [markdown]
# Используем набор данных `moscow_malls_info.csv` с информацией о торговых центрах Москвы.
#
# Датасет хранит следующие данные:
#
# - `name` — название торгового центра;
# - `address` — адрес торгового центра;
# - `hours` — часы работы торгового центра;
# - `lat` — широта точки, в которой находится объект;
# - `lng` — долгота точки, в которой находится объект;
# - `rating` — рейтинг центра на Яндекс Картах;
# - `district` — район Москвы, в котором находится объект.
#
# Исследуем набор данных:

# %%
import pandas as pd

df = pd.read_csv('/datasets/moscow_malls_info.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      786 non-null    object
#  1   address   786 non-null    object
#  2   hours     685 non-null    object
#  3   lat       786 non-null    float64
#  4   lng       786 non-null    float64
#  5   rating    786 non-null    float64
#  6   district  764 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 43.1+ KB

# %% [markdown]
# Датасет хранит информацию о 786 торговых центрах.
#
# Посмотрим на первые строки:

# %%
df.head()
# Out:
#         name                                   address  \
# 0  Капитолий           Москва, Правобережная улица, 1Б
# 1     Dexter  Москва, МКАД, 78-й километр, 14, корп. 1
# 2        РИО  Москва, Дмитровское шоссе, 163А, корп. 1
# 3    Экстрим               Москва, Смольная улица, 63Б
# 4  Discovery                Москва, улица Дыбенко, 7/1
#
#                     hours        lat        lng  rating  \
# 0  ежедневно, 10:00–22:00  55.880803  37.449824     4.7
# 1  ежедневно, 10:00–21:00  55.893082  37.501263     4.3
# 2  ежедневно, 10:00–22:00  55.909388  37.539546     4.8
# 3  ежедневно, 10:00–21:00  55.869937  37.469915     4.7
# 4  ежедневно, 09:00–21:00  55.878662  37.479251     4.3
#
#                                   district
# 0          Северный административный округ
# 1          Северный административный округ
# 2  Северо-Восточный административный округ
# 3          Северный административный округ
# 4          Северный административный округ

# %% [markdown]
# Отметим первые 5 заведений на карте:

# %%
# подключаем библиотеку
from folium import Marker, Map

# moscow_lat - широта, moscow_lng – долгота
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера к первым 5 записям датафрейма
df[:5].apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8c02ffabd4510200576fb21d407f3cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8c02ffabd4510200576fb21d407f3cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e8c02ffabd4510200576fb21d407f3cb = L.map(
#                 &quot;map_e8c02ffabd4510200576fb21d407f3cb&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9f950fb2b72393f9583ed10194e5652 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e8c02ffabd4510200576fb21d407f3cb);
#
#
#             var marker_8afb11098df0dfc0077453e64bca45e4 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_e8c02ffabd4510200576fb21d407f3cb);
#
#
#         var popup_29ab3d27dc75e9d2b54b3ec77453e188 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_76ca91900469197e1c9a8af2a9f99933 = $(`&lt;div id=&quot;html_76ca91900469197e1c9a8af2a9f99933&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_29ab3d27dc75e9d2b54b3ec77453e188.setContent(html_76ca91900469197e1c9a8af2a9f99933);
#
#
#         marker_8afb11098df0dfc0077453e64bca45e4.bindPopup(popup_29ab3d27dc75e9d2b54b3ec77453e188)
#         ;
#
#
#
#
#             var marker_aac06db1d67c1684a5f961d7e5b31e45 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_e8c02ffabd4510200576fb21d407f3cb);
#
#
#         var popup_04979d05afd978fdd602cfb2b384bc74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e26dbdcc0fbda56e545a7d364b9ea30 = $(`&lt;div id=&quot;html_7e26dbdcc0fbda56e545a7d364b9ea30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_04979d05afd978fdd602cfb2b384bc74.setContent(html_7e26dbdcc0fbda56e545a7d364b9ea30);
#
#
#         marker_aac06db1d67c1684a5f961d7e5b31e45.bindPopup(popup_04979d05afd978fdd602cfb2b384bc74)
#         ;
#
#
#
#
#             var marker_4b087ddc11ab7379aba4d62dbfcea337 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_e8c02ffabd4510200576fb21d407f3cb);
#
#
#         var popup_db3b3a3b8b9466f16f026916c593b508 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_42d040d8819253603393caa86af258d0 = $(`&lt;div id=&quot;html_42d040d8819253603393caa86af258d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_db3b3a3b8b9466f16f026916c593b508.setContent(html_42d040d8819253603393caa86af258d0);
#
#
#         marker_4b087ddc11ab7379aba4d62dbfcea337.bindPopup(popup_db3b3a3b8b9466f16f026916c593b508)
#         ;
#
#
#
#
#             var marker_253f61becfa7493d23f171e883054de4 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_e8c02ffabd4510200576fb21d407f3cb);
#
#
#         var popup_a58bf47dc737afe0c03de0c1d16b0343 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8099b5e8926201a63ec88a4e110b84c5 = $(`&lt;div id=&quot;html_8099b5e8926201a63ec88a4e110b84c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_a58bf47dc737afe0c03de0c1d16b0343.setContent(html_8099b5e8926201a63ec88a4e110b84c5);
#
#
#         marker_253f61becfa7493d23f171e883054de4.bindPopup(popup_a58bf47dc737afe0c03de0c1d16b0343)
#         ;
#
#
#
#
#             var marker_ef7d3f0bcbccf19996d4629aaffdf199 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_e8c02ffabd4510200576fb21d407f3cb);
#
#
#         var popup_2957cfa8baf230b9adec51ec4ba851ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ea5ec1954173525b87f07276b6e95f1a = $(`&lt;div id=&quot;html_ea5ec1954173525b87f07276b6e95f1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#             popup_2957cfa8baf230b9adec51ec4ba851ca.setContent(html_ea5ec1954173525b87f07276b6e95f1a);
#
#
#         marker_ef7d3f0bcbccf19996d4629aaffdf199.bindPopup(popup_2957cfa8baf230b9adec51ec4ba851ca)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# А теперь отметим сразу все здания:

# %%
# подключаем библиотеку
from folium import Marker

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера ко всем строкам датафрейма
df.apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ca9e3adbbc92712308e369bfcfd6bf4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ca9e3adbbc92712308e369bfcfd6bf4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2ca9e3adbbc92712308e369bfcfd6bf4 = L.map(
#                 &quot;map_2ca9e3adbbc92712308e369bfcfd6bf4&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eff5fa215ec6bcf213424cc2381d7a72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ca9e3adbbc92712308e369bfcfd6bf4);
#
#
#             var marker_4da2381bdcd671b867761c89c14123bb = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_2ca9e3adbbc92712308e369bfcfd6bf4);
#
#
#         var popup_2f99877e3f5fa3eeec5d2d4a637ab51a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a8b6ac69929ee8c24bcddfb61135597b = $(`&lt;div id=&quot;html_a8b6ac69929ee8c24bcddfb61135597b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_2f99877e3f5fa3eeec5d2d4a637ab51a.setContent(html_a8b6ac69929ee8c24bcddfb61135597b);
#
#
#         marker_4da2381bdcd671b867761c89c14123bb.bindPopup(popup_2f99877e3f5fa3eeec5d2d4a637ab51a)
#         ;
#
#
#
#
#             var marker_47a1f1373d41fe07004e9aee41340ddb = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_2ca9e3adbbc92712308e369bfcfd6bf4);
#
#
#         var popup_51ee146b74d15408e6b8254d2d16022f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6f91b26b9193dd58805801b7ce744f7a = $(`&lt;div id=&quot;html_6f91b26b9193dd58805801b7ce744f7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_51ee146b74d15408e6b8254d2d16022f.setContent(html_6f91b26b9193dd58805801b7ce744f7a);
#
#
#         marker_47a1f1373d41fe07004e9aee41340ddb.bindPopup(popup_51ee146b74d15408e6b8254d2d16022f)
#         ;
#
#
#
#
#             var marker_b1420174cfd0f148ece50b2a9a7aed18 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_2ca9e3adbbc92712308e369bfcfd6bf4);
#
#
#         var popup_cceba84dece883eef04ede76b001be89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3476bbfefed9e4a8b697c79a985ad608 = $(`&lt;div id=&quot;html_3476bbfefed9e4a8b697c79a985ad608&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_cceba84dece883eef04ede76b001be89.setContent(html_3476bbfefed9e4a8b697c79a985ad608);
#
#
#         marker_b1420174cfd0f148ece50b2a9a7aed18.bindPopup(popup_cceba84dece883eef04ede76b001be89)
#         ;
#
#
#
#
#             var marker_b83bffb2d6bf6e32d889cbed045fe6c7 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_2ca9e3adbbc92712308e369bfcfd6bf4);
#
#
#         var popup_26f4e9b68153bd23cb2138c6420ebb52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_86a695bdb5d4b9a10340f06f1fafb509 = $(`&lt;div id=&quot;html_86a695bdb5d4b9a10340f06f1fafb509&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_26f4e9b68153bd23cb2138c6420ebb52.setContent(html_86a695bdb5d4b9a10340f06f1fafb509);
#
#
#         marker_b83bffb2d6bf6e32d889cbed045fe6c7.bindPopup(popup_26f4e9b68153bd23cb2138c6420ebb52)
#         ;
#
#
#
#
#             var marker_1a644234a391f94152854cfeca36032d = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_2ca9e3adbbc92712308e369bfcfd6bf4);
#
#
#         var popup_71d08650499a7f5cdfccd76dd9fbe3ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_afe0bd110c2002d67188d7ad920ca489 = $(`&lt;div id=&quot;html_afe0bd110c2002d67188d7ad920ca489&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#             popup_71d08650499a7f5cdfccd76dd9fbe3ac.setContent(html_afe0bd110c2002d67188d7ad920ca489);
#
#
#         marker_1a644234a391f94152854cfeca36032d.bindPopup(popup_71d08650499a7f5cdfccd76dd9fbe3ac)
#         ;
#
#
#
#
#             var marker_ca6f5eeebe9d816ce377c0a9dc456836 = L.marker(
#                 [55.893181, 37.50108],
#                 {}
#             ).addTo(map_2ca9e3adbbc92712308e369bfcfd6bf4);
#
#
#         var popup_f2bf6d86902f9c1e8c5e76da5ada854c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3d9745e99ce43de0860dd0cfce355841 = $(`&lt;div id=&quot;html_3d9745e99ce43de0860dd0cfce355841&quot; style=&quo

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# - Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# - Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# - Из-за высокой нагрузки карта может зависать при передвижении по ней.
#
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
df.apply(create_clusters, axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecd5ca0c10cc04e2e81824c01a714221 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecd5ca0c10cc04e2e81824c01a714221&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ecd5ca0c10cc04e2e81824c01a714221 = L.map(
#                 &quot;map_ecd5ca0c10cc04e2e81824c01a714221&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8a304088d2c33f7a3df895758ec5d86 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ecd5ca0c10cc04e2e81824c01a714221);
#
#
#             var marker_cluster_1778b8004ff6cdc6a0d2a120a0c6a723 = L.markerClusterGroup(
#                 {}
#             );
#             map_ecd5ca0c10cc04e2e81824c01a714221.addLayer(marker_cluster_1778b8004ff6cdc6a0d2a120a0c6a723);
#
#
#             var marker_d4d1483750e7e053f1f28bf71a736d18 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_1778b8004ff6cdc6a0d2a120a0c6a723);
#
#
#         var popup_57c8156bc2f0b095ae0fad1fbc2d5576 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_67647d5bc3591b05e5bd4bd002f753bd = $(`&lt;div id=&quot;html_67647d5bc3591b05e5bd4bd002f753bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_57c8156bc2f0b095ae0fad1fbc2d5576.setContent(html_67647d5bc3591b05e5bd4bd002f753bd);
#
#
#         marker_d4d1483750e7e053f1f28bf71a736d18.bindPopup(popup_57c8156bc2f0b095ae0fad1fbc2d5576)
#         ;
#
#
#
#
#             var marker_d97dccd736aee673862dbc283bed7ae8 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_1778b8004ff6cdc6a0d2a120a0c6a723);
#
#
#         var popup_903df0819116485fcb16c8a7333551a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b364ee6403978909b8cbff2a4efe7a65 = $(`&lt;div id=&quot;html_b364ee6403978909b8cbff2a4efe7a65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_903df0819116485fcb16c8a7333551a4.setContent(html_b364ee6403978909b8cbff2a4efe7a65);
#
#
#         marker_d97dccd736aee673862dbc283bed7ae8.bindPopup(popup_903df0819116485fcb16c8a7333551a4)
#         ;
#
#
#
#
#             var marker_d723041159723ca0b0a945bdff10e9f2 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_1778b8004ff6cdc6a0d2a120a0c6a723);
#
#
#         var popup_669b9590420b097bae858b4c685bae69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4903f61f6d1a8afe4d98d5caa565bc3d = $(`&lt;div id=&quot;html_4903f61f6d1a8afe4d98d5caa565bc3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_669b9590420b097bae858b4c685bae69.setContent(html_4903f61f6d1a8afe4d98d5caa565bc3d);
#
#
#         marker_d723041159723ca0b0a945bdff10e9f2.bindPopup(popup_669b9590420b097bae858b4c685bae69)
#         ;
#
#
#
#
#             var marker_96f04cf858cc8a3a905320709d13b7df = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_1778b8004ff6cdc6a0d2a120a0c6a723);
#
#
#         var popup_5bc1bd0800c75c39c9f1a65ba13d9e04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2726b113d301693f345b416ea8e730b0 = $(`&lt;div id=&quot;html_2726b113d301693f345b416ea8e730b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_5bc1bd0800c75c39c9f1a65ba13d9e04.setContent(html_2726b113d301693f345b416ea8e730b0);
#
#
#         marker_96f04cf858cc8a3a905320709d13b7df.bindPopup(popup_5bc1bd0800c75c39c9f1a65ba13d9e04)
#         ;
#
#
#
#
#             var marker_e2e82cfb9d37d75a088aa2d75382f3b2 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(marker_cluster_1778b8004ff6cdc6a0d2a120a0c6a723);
#
#
#         var popup_4ec58743cd521dd2f043e6a10d93f1d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_794b02998d7eb13145629d8bd3d9e2b1 = $(`&lt;div id=&quot;html_794b02998d7eb13145629d8bd3d9e2b1&quot; style=&quot;width: 100.0

# %% [markdown]
# Попробуйте увеличить масштаб с помощью колёсика мышки или кнопок на карте. Вы увидите, что кластеры автоматически перегруппировываются: при достаточном приближении из кластеров начнут «выпадать» отдельные маркеры с торговыми центрами. Всплывающие окна и подсказки для них реализованы точно так же, как и для отдельных маркеров.
